# %% [markdown]
# ## Problem Formulation
#
# **Domain:** Startup Analytics / Entrepreneurship
# **Problem Statement:**  Early identification of factors that influence startup success or failure.
#
# **Main Question:**
#
# What factors most strongly predict whether a startup will succeed or fail?
#
# ## Plan Table
# - Kaggle datasets
# - one scrapped - google trends
#
# | **Data Source**                                                                                                                            | **Type of Data**                                                                                         | **Collection Mode**    | **Format**        | **Sampling**                             | **Storage**         | **Description / Purpose**                                                                                     |
# | ------------------------------------------------------------------------------------------------------------------------------------------ | -------------------------------------------------------------------------------------------------------- | ---------------------- | ----------------- | ---------------------------------------- | ------------------- | ------------------------------------------------------------------------------------------------------------- |
# | [Startup Failure Prediction Dataset](https://www.kaggle.com/datasets/sakharebharat/startup-failure-prediction-dataset)                     | Quantitative (Funding_Amount, Revenue) + Qualitative (Market_Size, Startup_Status)                       | Downloaded             | `.csv`            | No                                       | Local storage / API | Used to analyze whether a startup can fail based on market and funding variables.                             |
# | [Startup Growth and Funding Trends](https://www.kaggle.com/datasets/samayashar/startup-growth-and-funding-trends)                          | Quantitative (Funding_Amount, Growth_Rate, Valuation) + Qualitative (Industry, Location)                 | Downloaded             | `.csv`            | No                                       | Local storage / API | Used to analyze growth and profitability trends across industries and funding stages.                         |                        |
# | Scraped / Custom Dataset ( Product Hunt APn)                                                                | Qualitative (Founder Experience, Risk Factors) + Quantitative (Years Active) | Scraped / Manual Entry | `.csv` | No                                       | Local storage       | Created to add contextual or qualitative attributes not found in Kaggle datasets — complements main datasets. |

# %%
import pandas as pd

data = pd.read_csv("/content/startup_failure_prediction.csv")

# %%
data
# Out:
#       Startup_Name    Industry  Startup_Age  Funding_Amount  \
# 0        Startup_1   Logistics            8        18328419
# 1        Startup_2   Education            3        39753708
# 2        Startup_3  Healthcare           14        18073294
# 3        Startup_4  E-commerce            5        19435653
# 4        Startup_5     Finance           14         4205797
# ...            ...         ...          ...             ...
# 4995  Startup_4996   Education            9        39609909
# 4996  Startup_4997       AI/ML            7        32167694
# 4997  Startup_4998   Logistics           13        38902583
# 4998  Startup_4999   Education            2        33410138
# 4999  Startup_5000  Healthcare            1        42246335
#
#       Number_of_Founders  Founder_Experience  Employees_Count   Revenue  \
# 0                      2                  13              581  97866143
# 1                      3                  16              529  36868744
# 2                      1                  28               82   3478737
# 3                      4                  14              234  80716899
# 4                      4                  17              960  53347246
# ...                  ...                 ...              ...       ...
# 4995                   4                  13              324  16090631
# 4996                   3                  17              673  72563900
# 4997                   4                  14              253  66629971
# 4998                   4                  16              417  69293233
# 4999                   1                  29              708  53330079
#
#       Burn_Rate Market_Size Business_Model  Product_Uniqueness_Score  \
# 0        602731      Medium            B2B                         2
# 1        820698       Large            B2C                         3
# 2        992205       Small            B2C                         1
# 3        536747      Medium            B2C                         9
# 4        555199      Medium         Hybrid                         3
# ...         ...         ...            ...                       ...
# 4995     971733       Small            B2B                         7
# 4996     148322       Large            B2C                         5
# 4997     487704      Medium            B2C                         6
# 4998     723237      Medium            B2B                         9
# 4999     962039       Large            B2C                         7
#
#       Customer_Retention_Rate  Marketing_Expense  Startup_Status
# 0                       79.61             987830               1
# 1                       32.47             599615               1
# 2                        9.88             780730               1
# 3                       23.20             188588               1
# 4                       73.52             310892               1
# ...                       ...                ...             ...
# 4995                    21.56             568646               1
# 4996                    89.58             466261               1
# 4997                    17.21             468514               1
# 4998                    39.35             134880               1
# 4999                    16.32             217733               1
#
# [5000 rows x 15 columns]
